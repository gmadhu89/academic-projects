# %%
import pandas as pd

# %%
df1 = pd.read_csv('D:/PhD VIII/CSE 6242/Proj_6242/CSE-6242-Project/DB/player_country_1.csv')
df2 = pd.read_csv('D:/PhD VIII/CSE 6242/Proj_6242/CSE-6242-Project/DB/player_country_2.csv')
df3 = pd.read_csv('D:/PhD VIII/CSE 6242/Proj_6242/CSE-6242-Project/DB/player_country_3.csv')
df4 = pd.read_csv('D:/PhD VIII/CSE 6242/Proj_6242/CSE-6242-Project/DB/player_country_4.csv')

# %%
df = df1.append(df2).append(df3).append(df4)

# %%
df.to_csv('D:/PhD VIII/CSE 6242/Proj_6242/CSE-6242-Project/DB/player_country.csv', index=False)

# %%
df.groupby(df.country_code).count()
# Out:
#               user_id  steam_id
# country_code
# AD                  1         1
# AE                  1         1
# AF                  2         2
# AG                  1         1
# AL                  3         3
# AO                  1         1
# AQ                  2         2
# AR                 21        21
# AS                  1         1
# AT                  7         7
# AU                 28        28
# AX                  2         2
# AZ                  2         2
# BE                  9         9
# BG                  2         2
# BN                  1         1
# BO                  2         2
# BQ                  1         1
# BR                 80        80
# BS                  1         1
# BY                  6         6
# BZ                  1         1
# CA                 43        43
# CG                  1         1
# CH                  4         4
# CL                 15        15
# CN                166       166
# ...
